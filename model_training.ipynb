# %%
import pandas as pd

df = pd.read_csv('house_price.csv')
df.head()
# Out:
#    area  bedrooms  age     price
# 0  3154         3   16  688000.0
# 1  1666         3   45  386000.0
# 2  2977         4   31  674000.0
# 3  1241         2   28  325000.0
# 4  2573         3   49  548000.0

# %%
import matplotlib.pyplot as plt

plt.scatter(df['area'], df['price'])
plt.xlabel('Area (sq ft)')
plt.ylabel('Price ($)')
plt.title('House Price vs Area')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(df[['area', 'bedrooms', 'age']], df['price'])
# Out:
# LinearRegression()

# %%
model.predict([[3000, 3, 16]])

681246.9492253473
# Out:
# c:\Users\Vinyas Bharadwaj\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([681246.94922535])

# %%
import pickle 

with open("model.pkl", "wb") as file:
    pickle.dump(model, file)
